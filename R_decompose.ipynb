# %% [markdown]
# <a href="https://colab.research.google.com/github/KoMurase/-/blob/master/R_decompose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
y<-c(108.5, 117, 125.3, 111, 108.7, 115.9, 117.9, 101.2, 116.9, 111.7, 100.6,+
+ 93.7, 76.6, 73.5, 84.3, 77.7, 77.3, 89.3, 91.3, 82.3, 96.1, 95.7, 96.6, 97.6,+
+ 88.8, 94.7, 108.9, 96.2, 92.1, 103.9, 104.8, 95.7, 108.4, 100.3, 103.2, +
+ 102.9, 92.7, 98.5, 94.4, 83.3, 87.4, 102.4, 102.1, 96.7, 105.1, 101.8, 100.7,+
+ 101, 92.8, 101.5, 110.1, 95.9, 94, 101.8, 102.2, 92.7, 97.1, 97, 95.2, 93.3,+
+ 86.9, 91.4, 102.4, 92.8, 93.1, 97, 104.1, 92.1, 102.2, 102.2, 99.8, 100, +
+ 96.2, 97.8, 110, 96.2, 94, 100.1, 103.6, 89.3, 103.2, 101.7, 96.1, 99.9,+
+ 93.7, 95.5, 107.8, 96, 89.8, 102.2, 103, 88.5, 102, 100.1, 97.4, +
+ 97.8, 90.2, 94.5, 108.2, 92.9, 89.3, 100.6, 98.7, 92.5, 103.5, 98.9, 101.7,+
+ 100.8, 93.1, 98.9, 112, 98.2, 95.1, 106.1, 103.3, 97.4, 106.2, 104.7)

# %%
y <- ts(y, start = c(2008, 1), end = c(2017, 10), frequency = 12)

# %% [markdown]
# decomposeは時系列データをtrend + cycle + randomに分ける関数

# %%
v <- decompose(y)

# %%
v
# Out:
# $x
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# 2008 108.5 117.0 125.3 111.0 108.7 115.9 117.9 101.2 116.9 111.7 100.6  93.7
# 2009  76.6  73.5  84.3  77.7  77.3  89.3  91.3  82.3  96.1  95.7  96.6  97.6
# 2010  88.8  94.7 108.9  96.2  92.1 103.9 104.8  95.7 108.4 100.3 103.2 102.9
# 2011  92.7  98.5  94.4  83.3  87.4 102.4 102.1  96.7 105.1 101.8 100.7 101.0
# 2012  92.8 101.5 110.1  95.9  94.0 101.8 102.2  92.7  97.1  97.0  95.2  93.3
# 2013  86.9  91.4 102.4  92.8  93.1  97.0 104.1  92.1 102.2 102.2  99.8 100.0
# 2014  96.2  97.8 110.0  96.2  94.0 100.1 103.6  89.3 103.2 101.7  96.1  99.9
# 2015  93.7  95.5 107.8  96.0  89.8 102.2 103.0  88.5 102.0 100.1  97.4  97.8
# 2016  90.2  94.5 108.2  92.9  89.3 100.6  98.7  92.5 103.5  98.9 101.7 100.8
# 2017  93.1  98.9 112.0  98.2  95.1 106.1 103.3  97.4 106.2 104.7
#
# $seasonal
#            Jan       Feb       Mar       Apr       May       Jun       Jul
# ...

# %%
plot(v)
# Out:
# plot without title
